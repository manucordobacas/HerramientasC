# %% [markdown]
# # Titulo mayor: primeros pasos en python
# ## subtitulo
# **subrayado**
# $$5*4$$

# %%
print("hola mundo")
nombre = "Juan"
print (nombre)
# Out:
# hola mundo
# Juan

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pri("hola mundo")
#
# NameError: name 'pri' is not defined
