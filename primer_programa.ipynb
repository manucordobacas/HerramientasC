# %% [markdown]
# # Titulo mayor: primeros pasos en python
# ## subtitulo
# **subrayado**
# $$5*4$$

# %%
print("hola mundo")
nombre = "Juan"
print (nombre)
print(type(nombre))
letra = "a"
print(type(letra)) #jajajajaj
# Out:
# hola mundo
# Juan
# <class 'str'>
# <class 'str'>

# %%
ciudad = "Medellin"
semestre = 1
universidad = "EIA"
print(ciudad,semestre,universidad)
# Out:
# Medellin 1 EIA

# %% [markdown]
# ## tipos de datos
# - int
# - float
# - string
# - bool

# %% [markdown]
# # operadores aritméticos
# - suma: +
# - resta: -
# - multiplicación: *
# - división: /
# - divisioón entero: //
# - residuo: %
# - potencia: **
# - multiplicacion de matrices:&

# %% [markdown]
# # Operadores lógicos de comparación
# - <>
# - ==
# - !=

# %% [markdown]
# # Entrada y salida de datos

# %%
nombre=input("Ingrese su nombre: ")
print("hola",nombre)
# Out:
# hola hola

# %%
edad = int(input("ingrese su edad:"))
print(edad)
print(type(edad))
# Out:
# 56
# <class 'int'>

# %% [markdown]
# # Ejercicios
# - 1. Escriba un programa que muestre un mensaje de bienvenida, utilizando al menos 4 intstrucciones print
# - 2. Cree variables para almacenar su nombre carrera semestre y promedio, imprima toda la información
# - 3. Solicite el nombre del usuario y saludelo con un mensaje personalizado
# - 4. solicite dos numeros enteros y calcule la suma la resta la multiplicacion y la division
# - 5. Solicite el radio de un circulo y calcule diametro, perimetro y area, teniendo en cuenta que pi es 3.1416

# %% [markdown]
# # ejercicio 1

# %%
print ("Hola") 
print ("Bienvenido a")
print ("mi primer")
print("codigo")
# Out:
# Hola
# Bienvenido a
# mi primer
# codigo

# %% [markdown]
# # ejercicio 2

# %%
Nombre = input("escribba su nombre:")
Carrera = input("escriba la carrera que cursa:")
semestre = input("¿qué semestre cursa?:")
promedio = int(input("¿su promedio?:"))
print ("Hola",Nombre,"usted cursa la carrera de",Carrera,semestre"en el semestre","y su promedio es de",promedio)
# Out:
# Hola manuela usted cursa la carrera de fisica en el semestre segundo y su promedio es de 5

# %% [markdown]
# # Tercer ejercicio

# %%
Nombre=input("escriba su nombre")
print("Hola", Nombre, "Bienvenida a mi primer programa")
# Out:
# Hola manuela Bienvenida a mi primer programa

# %% [markdown]
# # Ejercicio 4

# %%
Num1=int(input("escriba un numero entero:"))
Num2=int(input("escriba otro numero entero:"))
print ("la suma de los dos numeros es",Num1+Num2,"la multtiplicacion de los dos numeros es",Num1*Num2,"la resta de los dos numeros es",Num1-Num2,"y la division de los dos numeros es",Num1/Num2)
# Out:
# la suma de los dos numeros es 9 la multtiplicacion de los dos numeros es 20 la resta de los dos numeros es -1 y la division de los dos numeros es 0.8

# %% [markdown]
# # ejercicio 5

# %%
pi=3.1614
radio=float(input("ingrese el radio de un circulo:"))
print("El diametro del circulo es", 2*radio)
print("El perimetro del circulo es", 2*pi*radio)
print("El area del circulo es", pi*radio**2)
# Out:
# El diametro del circulo es 8.0
# El perimetro del circulo es 25.2912
# El area del circulo es 50.5824

# %% [markdown]
# # conversion de tipos
# - cuando convierto cualquier dato a un dato booleal, el toma todo lo distinto de cero como verdadero y el cero falso

# %%
print(bool(0))
print(bool(1))
print(bool(-5))
print(bool(3.14))
print(bool("Hello, World!"))
print(bool([]))
print(bool([1, 2, 3]))
# Out:
# False
# True
# True
# True
# True
# False
# True

# %%
numero="25.5"
resultado=float(numero)+2
print resultado 

numero1= "25.5"
resultado1=int(float(numero1)) #me da la parte entera del numero
print resultado1

# %% [markdown]
# # comparacionales
# == compara, = asigna un valor
# and es y, o es or

# %%
edad =16
nota=3
resultado=(edad>18 and nota>=3)
print(resultado)
# Out:
# False

# %%
promedio=3.7
programa_especial= True
resultado=promedio>=4 or programa_especial
print (resultado)
# Out:
# True

# %% [markdown]
# # funciones  integradas

# %%
x=25
y=3.1416
print(type(x))

nombre="alejandro"
print(len(nombre)) #la longitud de la cadena de texto, cuenta los espacios
print(round(y,3))
print(max(x,y))
print(sum(x,y))

#usar snake_case para nombrar variables, funciones y metodos, separa entradas, procesamiento y salida
# Out:
# <class 'int'>
# 9
